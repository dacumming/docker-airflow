# %%
from sqlalchemy import *
import pandas as pd
pd.set_option("display.max_columns", None)
import os

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/airflow')
cwd = os.getcwd()
path = os.path.join(cwd,'dags/fma_metadata/tracks.csv')
df = pd.read_csv(path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,1,5,6,8,12,18,20,21,22,24,33,34,38,39,44,47,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=df.rename(columns={'Unnamed: 0':'track_id','album.1':'album_date_created','album.5':'album_id'
                  ,'album.10':'album_title','artist.7':'artist_id','artist':'artist_'
                  ,'artist.12':'artist','set':'set_','set.1':'set','track.6':'track_favs','track.7':'genre'
                  ,'track.14':'listens','track.19':'title'})\
.set_index('track_id')\
.drop(columns=['album','album.3','album.6','album.8','album.9','album.11','album.12','artist_','artist.1','artist.2'
              ,'artist.4','artist.5','artist.8','artist.9','artist.10','artist.11','artist.13','artist.14','artist.15'
              ,'artist.16','set_','track','track.1','track.2','track.3','track.4','track.5','track.8','track.9','track.10'
              ,'track.11','track.12','track.13','track.15','track.16','track.17','track.18','artist.3','album.2'
              ,'album.4','artist.6','album.7'])\
.iloc[2: , :]

# %%
df=df.loc[df['set']=='small'].drop(columns=['set'])

# %%
df
# Out:
#            album_date_created album_id  \
# track_id
# 2         2008-11-26 01:44:45        1
# 5         2008-11-26 01:44:45        1
# 10        2008-11-26 01:45:08        6
# 140       2008-11-26 01:49:59       61
# 141       2008-11-26 01:49:57       60
# ...                       ...      ...
# 154308    2017-03-05 04:57:38    22780
# 154309    2017-03-05 04:57:38    22780
# 154413    2017-03-07 18:44:11    22789
# 154414    2017-03-07 18:44:11    22789
# 155066    2017-03-24 19:40:34    22899
#
#                                                 album_title artist_id  \
# track_id
# 2                                      AWOL - A Way Of Life         1
# 5                                      AWOL - A Way Of Life         1
# 10                                        Constant Hitmaker         6
# 140                                          The Blind Spot        54
# 141                                   Every Man For Himself        54
# ...

# %%
df.to_sql('tracks', engine, if_exists='replace', index=True,dtype={'track_id': Integer(), 'album_id': Integer(),
                                                                  'artist_id': Integer(), 'track_favs': Integer(),
                                                                  'listens': Integer(),
                                                                    'album_date_created':DateTime()})
engine.execute('alter table tracks add primary key(track_id	)')

# %%
def add_column(engine, table_name, column):
    column_name = column.compile(dialect=engine.dialect)
    column_type = column.type.compile(engine.dialect)
    engine.execute('ALTER TABLE %s ADD COLUMN %s %s' % (table_name, column_name, column_type))

# %%
track = Column('track', String(90))
bass = Column('bass', String(90))
drums = Column('drums', String(90))
other = Column('other', String(90))
vocals = Column('vocals', String(90))
track_spec = Column('track_spec', String(90))
bass_spec = Column('bass_spec', String(90))
drums_spec = Column('drums_spec', String(90))
other_spec = Column('other_spec', String(90))
vocals_spec = Column('vocals_spec', String(90))
add_column(engine, 'tracks', track)
add_column(engine, 'tracks', bass)
add_column(engine, 'tracks', drums)
add_column(engine, 'tracks', other)
add_column(engine, 'tracks', vocals)
add_column(engine, 'tracks', track_spec)
add_column(engine, 'tracks', bass_spec)
add_column(engine, 'tracks', drums_spec)
add_column(engine, 'tracks', other_spec)
add_column(engine, 'tracks', vocals_spec)
